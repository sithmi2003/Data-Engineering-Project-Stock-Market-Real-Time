# %%
# %pip install kafka-python pandas
# Out:
# Requirement already satisfied: kafka-python in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.0.0)
# Requirement already satisfied: pandas in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=2.3.3 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install boto3
# Out:
# Requirement already satisfied: boto3 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (1.43.29)
# Requirement already satisfied: botocore<1.44.0,>=1.43.29 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from boto3) (1.43.29)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from boto3) (1.1.0)
# Requirement already satisfied: s3transfer<0.19.0,>=0.18.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from boto3) (0.18.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from botocore<1.44.0,>=1.43.29->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from botocore<1.44.0,>=1.43.29->boto3) (2.7.0)
# Requirement already satisfied: six>=1.5 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.44.0,>=1.43.29->boto3) (1.17.0)
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import boto3

sts = boto3.client('sts')
print(sts.get_caller_identity())

# %%
import pandas as pd
from kafka import KafkaProducer
from time import sleep
from json import dumps
import json

# %%
producer = KafkaProducer(
    bootstrap_servers=['13.233.155.1:9092'],
    value_serializer=lambda x: dumps(x).encode('utf-8')
)

# %%
producer.send('demo_testing2', value={'name': 'SithAdi'})

# %%
df = pd.read_csv("Downloads/indexProcessed.csv")

# %%
df.head()
# Out:
#   Index        Date         Open         High          Low        Close  \
# 0   HSI  1986-12-31  2568.300049  2568.300049  2568.300049  2568.300049
# 1   HSI  1987-01-02  2540.100098  2540.100098  2540.100098  2540.100098
# 2   HSI  1987-01-05  2552.399902  2552.399902  2552.399902  2552.399902
# 3   HSI  1987-01-06  2583.899902  2583.899902  2583.899902  2583.899902
# 4   HSI  1987-01-07  2607.100098  2607.100098  2607.100098  2607.100098
#
#      Adj Close  Volume    CloseUSD
# 0  2568.300049     0.0  333.879006
# 1  2540.100098     0.0  330.213013
# 2  2552.399902     0.0  331.811987
# 3  2583.899902     0.0  335.906987
# 4  2607.100098     0.0  338.923013

# %%
while True:
    dict_stock = df.sample(1).to_dict(orient="records")[0]
    producer.send('demo_testing2', value=dict_stock)
    sleep(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 4
#       1 while True:
#       2     dict_stock = df.sample(1).to_dict(orient="records")[0]
#       3     producer.send('demo_testing2', value=dict_stock)
# ----> 4     sleep(1)
#
# KeyboardInterrupt:

# %%
producer.flush() #clear data from kafka server
